# %%
# !pip install rlcard

# %%
# !pip install pettingzoo

# %%
# !pip install pygame

# %%
print('Hello!')

# %%
from pettingzoo.classic import gin_rummy_v4

# %%
from pettingzoo.butterfly import cooperative_pong_v5

env = cooperative_pong_v5.env(render_mode="human")
env.reset(seed=42)

for agent in env.agent_iter():
    observation, reward, termination, truncation, info = env.last()

    if termination or truncation:
        action = None
    else:
        # this is where you would insert your policy
        action = env.action_space(agent).sample()

    env.step(action)
env.close()

# %%
# !pip install ollama
# Out:
# Collecting ollama
#   Obtaining dependency information for ollama from https://files.pythonhosted.org/packages/b5/c1/edc9f41b425ca40b26b7c104c5f6841a4537bb2552bfa6ca66e81405bb95/ollama-0.6.0-py3-none-any.whl.metadata
#   Downloading ollama-0.6.0-py3-none-any.whl.metadata (4.3 kB)
# Collecting httpx>=0.27 (from ollama)
#   Obtaining dependency information for httpx>=0.27 from https://files.pythonhosted.org/packages/2a/39/e50c7c3a983047577ee07d2a9e53faf5a69493943ec3f6a384bdc792deb2/httpx-0.28.1-py3-none-any.whl.metadata
#   Downloading httpx-0.28.1-py3-none-any.whl.metadata (7.1 kB)
# Collecting pydantic>=2.9 (from ollama)
#   Obtaining dependency information for pydantic>=2.9 from https://files.pythonhosted.org/packages/3e/d3/108f2006987c58e76691d5ae5d200dd3e0f532cb4e5fa3560751c3a1feba/pydantic-2.11.9-py3-none-any.whl.metadata
#   Downloading pydantic-2.11.9-py3-none-any.whl.metadata (68 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 68.4/68.4 kB 2.8 MB/s eta 0:00:00
# Collecting anyio (from httpx>=0.27->ollama)
#   Obtaining dependency information for anyio from https://files.pythonhosted.org/packages/15/b3/9b1a8074496371342ec1e796a96f99c82c945a339cd81a8e73de28b4cf9e/anyio-4.11.0-py3-none-any.whl.metadata
#   Downloading anyio-4.11.0-py3-none-any.whl.metadata (4.1 kB)
# Collecting certifi (from httpx>=0.27->ollama)
#   Obtaining dependency information for certifi from https://files.pythonhosted.org/packages/e5/48/1549795ba7742c948d2ad169c1c8cdbae65bc450d6cd753d124b17c8cd32/certifi-2025.8.3-py3-none-any.whl.metadata
#   Downloading certifi-2025.8.3-py3-none-any.whl.metadata (2.4 kB)
# Collecting httpcore==1.* (from httpx>=0.27->ollama)
#   Obtaining dependency information for httpcore==1.* from https://files.pythonhosted.org/packages/7e/f5/f66802a942d491edb555dd61e3a9961140fd64c90bce1eafd741609d334d/httpcore-1.0.9-py3-none-any.whl.metadata
#   Downloading httpcore-1.0.9-py3-none-any.whl.metadata (21 kB)
# Collecting idna (from httpx>=0.27->ollama)
#   Obtaining dependency information for idna from https://files.pythonhosted.org/packages/76/c6/c88e154df9c4e1a2a66ccf0005a88dfb2650c1dffb6f5ce603dfbd452ce3/idna-3.10-py3-none-any.whl.metadata
#   Downloading idna-3.10-py3-none-any.whl.metadata (10 kB)
# Collecting h11>=0.16 (from httpcore==1.*->httpx>=0.27->ollama)
#   Obtaining dependency information for h11>=0.16 from https://files.pythonhosted.org/packages/04/4b/29cac41a4d98d144bf5f6d33995617b185d14b22401f75ca86f384e87ff1/h11-0.16.0-py3-none-any.whl.metadata
#   Downloading h11-0.16.0-py3-none-any.whl.metadata (8.3 kB)
# Collecting annotated-types>=0.6.0 (from pydantic>=2.9->ollama)
#   Obtaining dependency information for annotated-types>=0.6.0 from https://files.pythonhosted.org/packages/78/b6/6307fbef88d9b5ee7421e68d78a9f162e0da4900bc5f5793f6d3d0e34fb8/annotated_types-0.7.0-py3-none-any.whl.metadata
#   Downloading annotated_types-0.7.0-py3-none-any.whl.metadata (15 kB)
# Collecting pydantic-core==2.33.2 (from pydantic>=2.9->ollama)
#   Obtaining dependency information for pydantic-core==2.33.2 from https://files.pythonhosted.org/packages/24/2f/3cfa7244ae292dd850989f328722d2aef313f74ffc471184dc509e1e4e5a/pydantic_core-2.33.2-cp311-cp311-macosx_11_0_arm64.whl.metadata
#   Downloading pydantic_core-2.33.2-cp311-cp311-macosx_11_0_arm64.whl.metadata (6.8 kB)
# Requirement already satisfied: typing-extensions>=4.12.2 in /Users/nimakelidari/Desktop/Master-USC/Deep Learning/Adversarial_Co-Evolution/.venv/lib/python3.11/site-packages (from pydantic>=2.9->ollama) (4.15.0)
# Collecting typing-inspection>=0.4.0 (from pydantic>=2.9->ollama)
#   Obtaining dependency information for typing-inspection>=0.4.0 from https://files.pythonhosted.org/packages/17/69/cd203477f944c353c31bade965f880aa1061fd6bf05ded0726ca845b6ff7/typing_inspection-0.4.1-py3-none-any.whl.metadata
#   Downloading typing_inspection-0.4.1-py3-none-any.whl.metadata (2.6 kB)
# Collecting sniffio>=1.1 (from anyio->httpx>=0.27->ollama)
#   Obtaining dependency information for sniffio>=1.1 from https://files.pythonhosted.org/packages/e9/44/75a9c9421471a6c4805dbf2356f7c181a29c1879239abab1ea2cc8f38b40/sniffio-1.3.1-py3-none-any.whl.metadata
#   Downloading sniffio-1.3.1-py3-none-any.whl.metadata (3.9 kB)
# Downloading ollama-0.6.0-py3-none-any.whl (14 kB)
# Downloading httpx-0.28.1-py3-none-any.whl (73 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 73.5/73.5 kB 7.2 MB/s eta 0:00:00
# Downloading httpcore-1.0.9-py3-none-any.whl (78 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 78.8/78.8 kB 8.3 MB/s eta 0:00:00
# Downloading pydantic-2.11.9-py3-none-any.whl (444 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 444.9/444.9 kB 9.6 MB/s eta 0:00:00ta 0:00:01
# Downloading pydantic_core-2.33.2-cp311-cp311-macosx_11_0_arm64.whl (1.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.9/1.9 MB 32.7 MB/s eta 0:00:00a 0:00:01
# Downloading annotated_types-0.7.0-py3-none-any.whl (13 kB)
# Downloading typing_inspection-0.4.1-py3-none-any.whl (14 kB)
# Downloading anyio-4.11.0-py3-none-any.whl (109 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 109.1/109.1 kB 17.6 MB/s eta 0:00:00
# Downloading idna-3.10-py3-none-any.whl (70 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 70.4/70.4 kB 8.6 MB/s eta 0:00:00
# Downloading certifi-2025.8.3-py3-none-any.whl (161 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 161.2/161.2 kB 21.1 MB/s eta 0:00:00
# Downloading h11-0.16.0-py3-none-any.whl (37 kB)
# Downloading sniffio-1.3.1-py3-none-any.whl (10 kB)
# Installing collected packages: typing-inspection, sniffio, pydantic-core, idna, h11, certifi, annotated-types, pydantic, httpcore, anyio, httpx, ollama
# Successfully installed annotated-types-0.7.0 anyio-4.11.0 certifi-2025.8.3 h11-0.16.0 httpcore-1.0.9 httpx-0.28.1 idna-3.10 ollama-0.6.0 pydantic-2.11.9 pydantic-core-2.33.2 sniffio-1.3.1 typing-inspection-0.4.1
# WARNING: There was an error checking the latest version of pip.

# %%
from ollama import chat
from ollama import ChatResponse

response: ChatResponse = chat(model='qwen3-vl:2b', messages=[
  {
    'role': 'user',
    'content': 'Why is the sky blue?',
  },
])
print(response['message']['content'])
# or access fields directly from the response object
print(response.message.content)
# Out:
# ---------------------------------------------------------------------------
# ResponseError                             Traceback (most recent call last)
# Cell In[4], line 4
#       1 from ollama import chat
#       2 from ollama import ChatResponse
# ----> 4 response: ChatResponse = chat(model='DeepSeek-R1-0528-Qwen3-8B', messages=[
#       5   {
#       6     'role': 'user',
#       7     'content': 'Why is the sky blue?',
#       8   },
#       9 ])
#      10 print(response['message']['content'])
#      11 # or access fields directly from the response object
#
# File ~/Desktop/Master-USC/Deep Learning/Adversarial_Co-Evolution/.venv/lib/python3.11/site-packages/ollama/_client.py:351, in Client.chat(self, model, messages, tools, stream, think, format, options, keep_alive)
#     306 def chat(
#     307   self,
#     308   model: str = '',
#    (...)    316   keep_alive: Optional[Union[float, str]] = None,
#     317 ) -> Union[ChatResponse, Iterator[ChatResponse]]:
#     318   """
#     319   Create a chat response using the requested model.
#     320
#    (...)    349   Returns `ChatResponse` if `stream` is `False`, otherwise returns a `ChatResponse` generator.
#     350   """
# --> 351   return self._request(
#     352     ChatResponse,
#     353     'POST',
#     354     '/api/chat',
#     355     json=ChatRequest(
#     356       model=model,
#     357       messages=list(_copy_messages(messages)),
#     358       tools=list(_copy_tools(tools)),
#     359       stream=stream,
#     360       think=think,
#     361       format=format,
#     362       options=options,
#     363       keep_alive=keep_alive,
#     364     ).model_dump(exclude_none=True),
#     365     stream=stream,
#     366   )
#
# File ~/Desktop/Master-USC/Deep Learning/Adversarial_Co-Evolution/.venv/lib/python3.11/site-packages/ollama/_client.py:189, in Client._request(self, cls, stream, *args, **kwargs)
#     185         yield cls(**part)
#     187   return inner()
# --> 189 return cls(**self._request_raw(*args, **kwargs).json())
#
# File ~/Desktop/Master-USC/Deep Learning/Adversarial_Co-Evolution/.venv/lib/python3.11/site-packages/ollama/_client.py:133, in Client._request_raw(self, *args, **kwargs)
#     131   return r
#     132 except httpx.HTTPStatusError as e:
# --> 133   raise ResponseError(e.response.text, e.response.status_code) from None
#     134 except httpx.ConnectError:
#     135   raise ConnectionError(CONNECTION_ERROR_MESSAGE) from None
#
# ResponseError: model 'DeepSeek-R1-0528-Qwen3-8B' not found (status code: 404)

# %%
from pettingzoo.classic import gin_rummy_v4

env = gin_rummy_v4.env(render_mode="human")
env.reset(seed=42)

for agent in env.agent_iter():
    observation, reward, termination, truncation, info = env.last()

    if termination or truncation:
        action = None
    else:
        mask = observation["action_mask"]
        # this is where you would insert your policy
        action = env.action_space(agent).sample(mask)

    env.step(action)
env.close()
# Out:
# /Users/nimakelidari/miniconda3/envs/marl/lib/python3.11/site-packages/pygame/pkgdata.py:25: UserWarning: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html. The pkg_resources package is slated for removal as early as 2025-11-30. Refrain from using this package or pin to Setuptools<81.
#   from pkg_resources import resource_stream, resource_exists
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[1], line 16
#      13         # this is where you would insert your policy
#      14         action = env.action_space(agent).sample(mask)
# ---> 16     env.step(action)
#      17 env.close()
#
# File ~/miniconda3/envs/marl/lib/python3.11/site-packages/pettingzoo/utils/wrappers/order_enforcing.py:70, in OrderEnforcingWrapper.step(self, action)
#      68 else:
#      69     self._has_updated = True
# ---> 70     super().step(action)
#
# File ~/miniconda3/envs/marl/lib/python3.11/site-packages/pettingzoo/utils/wrappers/base.py:47, in BaseWrapper.step(self, action)
#      46 def step(self, action: ActionType) -> None:
# ---> 47     self.env.step(action)
#
# File ~/miniconda3/envs/marl/lib/python3.11/site-packages/pettingzoo/utils/wrappers/assert_out_of_bounds.py:26, in AssertOutOfBoundsWrapper.step(self, action)
#      16 def step(self, action: ActionType) -> None:
#      17     assert (
#      18         action is None
#      19         and (
#    (...)     24         action
#      25     ), "action is not in action space"
# ---> 26     super().step(action)
#
# File ~/miniconda3/envs/marl/lib/python3.11/site-packages/pettingzoo/utils/wrappers/base.py:47, in BaseWrapper.step(self, action)
#      46 def step(self, action: ActionType) -> None:
# ---> 47     self.env.step(action)
#
# File ~/miniconda3/envs/marl/lib/python3.11/site-packages/pettingzoo/utils/wrappers/terminate_illegal.py:78, in TerminateIllegalWrapper.step(self, action)
#      76     self._terminated = True
#      77 else:
# ---> 78     super().step(action)
#
# File ~/miniconda3/envs/marl/lib/python3.11/site-packages/pettingzoo/utils/wrappers/base.py:47, in BaseWrapper.step(self, action)
#      46 def step(self, action: ActionType) -> None:
# ---> 47     self.env.step(action)
#
# File ~/miniconda3/envs/marl/lib/python3.11/site-packages/pettingzoo/classic/rlcard_envs/rlcard_base.py:117, in RLCardBase.step(self, action)
#     114 self._deads_step_first()
#     116 if self.render_mode == "human":
# --> 117     self.render()
#
# File ~/miniconda3/envs/marl/lib/python3.11/site-packages/pettingzoo/classic/rlcard_envs/gin_rummy.py:393, in raw_env.render(self)
#     391 if self.render_mode == "human":
#     392     pygame.display.update()
# --> 393     self.clock.tick(self.metadata["render_fps"])
#     395 observation = np.array(pygame.surfarray.pixels3d(self.screen))
#     397 return (
#     398     np.transpose(observation, axes=(1, 0, 2))
#     399     if self.render_mode == "rgb_array"
#     400     else None
#     401 )
#
# KeyboardInterrupt:
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
